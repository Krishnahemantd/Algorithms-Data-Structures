# %%
import random


class Listnode(): # creating a standard listnode
    def __init__(self,key,level):
        self.key = key
        self.next = [None] * (level + 1) # creating references for level 
        
class skiplist():
    def __init__(self,maxlevel):
        self.max = maxlevel
        self.head = self.createnode(-1, self.max) # head for starting node
        self.level = 0 # current level 
        
    def createnode(self,level,key):
        node = Listnode(level,key)
        return node         
    
    def randomize_level(self):
        level = 0
        while random.choice([0,1]) == 1 and self.level < self.max:
            level += 1
        return level
        
    def lookup(self,key):
        curr = self.head

        for i in range(self.level, -1,-1):
            while(curr.next[i] and curr.next.key[i] < key):
                curr = curr.next[i]
            
        curr = curr.next[0]

        if curr is not None and curr.key == key:
            print("Key found" + str(key))

        
    def insert(self,key):
        curr = self.head 
        totallist = [None]*(self.max + 1)
        for i in range(self.level,-1,-1):
            while curr.next[i] and curr.key.next[i] < key: # stop before key 
                curr = curr.next[i] # keep moving in the linked list
            totallist[i] = curr
                
        curr = curr.next[0]

        if curr is None or  curr.key is not key:
            randomlevel = self.randomize_level()
            if randomlevel > self.level:
                for i in range(self.level + 1,randomlevel + 1):
                    totallist[i] = self.head
                self.level = randomlevel # We're at the desired level
            new = self.createnode(self.level,key) # made a new node in that level

            for i in range(self.level + 1):
                new.next[i] = totallist[i].next[i]
                totallist[i].next[i] = new 
            
    def delete(self,key):
        totallist = [None]*(self.max + 1)
        curr = self.head

        for i in range(self.level, -1,-1):
            while(curr.next[i] and curr.key.next[i] < key):
                curr = curr.next[i]
            totallist[i] = curr

        curr = curr.next[0]

        if curr is not None and curr.key == key:
            for i in range(self.level + 1):

                if totallist[i].next[i] is not curr:
                    break
                totallist[i].next[i] = curr.next[i]

            
            while(self.level > 0 and self.head.next[self.level] == None):
                self.level -= 1
                print("Deleted {}".format(key))

# %%
ss = skiplist(15)

ss.insert(key = 5)
ss.insert(key = 15)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23736\2789318039.py in <module>
#       2
#       3 ss.insert(key = 5)
# ----> 4 ss.insert(key = 15)
#
# ~\AppData\Local\Temp\ipykernel_23736\3518417433.py in insert(self, key)
#      40         totallist = [None]*(self.max + 1)
#      41         for i in range(self.level,-1,-1):
# ---> 42             while curr.next[i] and curr.next.key[i] < key: # stop before key
#      43                 curr = curr.next[i] # keep moving in the linked list
#      44             totallist[i] = curr
#
# AttributeError: 'list' object has no attribute 'key'
