# %%
import random


class Listnode(): # creating a standard listnode
    def __init__(self,key,level):
        self.key = key
        self.next = None * [level + 1] # creating references for level 
        
class skiplist():
    def __init__(self,maxlevel,frac):
        self.max = maxlevel
     #   self.frac = frac
        self.head = self.createnode(-1, self.max)
        self.level = 0 
        
    def createnode(self,level,key):
        node = Listnode(level,key)
        return node         
    
    def randomize_level(self):
        level = 0
        while random.choice([0,1]) == 1 and self.level < self.max:
            level += 1
        return level
        
    def lookup(self,key):
        curr = self.head

        for i in range(self.level, -1,-1):
            while(curr.next[i] and curr.next.key[i] < key):
                curr = curr.next[i]
            
        curr = curr.next[0]

        if curr is not None and curr.key == key:
            print("Key found" + str(key))

        
    def insert(self,key):
        curr = self.head 
        currlevel = self.randomize_level()
        while curr.next[i] and curr.next.key[i] < key: # stop before key 
            if key.next == curr.level.next: # insert
                return 
            else:
                curr = curr.next[i] # keep moving in the linked list
                
        else:
            while curr.level and curr.level.next < key:
                curr = curr.next
            
    def delete(self,key):
        update = [None]*(self.max + 1)
        curr = self.head

        for i in range(self.level, -1,-1):
            while(curr.next[i] and curr.next.key[i] < key):
                curr = curr.next[i]
            update[i] = curr

        curr = curr.next[0]

        if curr is not None and curr.key == key:
            for i in range(self.level + 1):

                if update[i].next[i] is not curr:
                    break
                update[i].next[i] = curr.next[i]

            
            while(self.level > 0 and self.head.next[self.level] == None):
                self.level -= 1
                print("Deleted {}".format(key))
