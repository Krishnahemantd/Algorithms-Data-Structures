# %%
import random


class Listnode(): # creating a standard listnode
    def __init__(self,key,level):
        self.key = key
        self.next = None * [level + 1] # creating references for level 
        
class skiplist():
    def __init__(self,maxlevel,frac):
        self.max = maxlevel
     #   self.frac = frac
        self.head = self.createnode(-1, self.max)
        self.level = 0 
        
    def createnode(self,level,key):
        node = Listnode(level,key)
        return node         
    
    def randomize_level(self):
        level = 0
        while random.choice([0,1]) == 1 and self.level < maxlevel:
            level += 1
        return level
        
    def lookup(self,key):
        curr = self.head
        for curr in range(self.level - 1, -1, -1):
            if curr 
        
    def insert(self,key):
        curr = self.head 
        currlevel = self.randomize_level()
        while curr.level and curr.level.next < key: # stop before key 
            if key.next == curr.level.next: # insert
                return 
            else:
                curr.level = curr.level.next # keep moving in the linked list
                
        else:
            while curr.level and curr.level.next < key:
                curr = curr.next
            
    def delete():
